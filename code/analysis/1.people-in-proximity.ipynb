# %% [markdown]
# How many people live near dangerous dams in Brazil and where in the territory are they distributed? Let's find out.

# %% [markdown]
# #### Importing packages

# %%
import geobr
import geopandas as gpd
import numpy as np
import pandas as pd
from shapely.geometry import Point
import tobler
from unidecode import unidecode

# %%
import warnings; warnings.filterwarnings('ignore', message='.*initial implementation of Parquet.*')

# %% [markdown]
# #### Data preparation

# %%
def read_dams():
    '''
    Reads the dam safety dataset using
    the appropriate configurations.
    '''

    dams = pd.read_csv("../../data/brazil/snisb/dam-report-07022021.csv", encoding='Latin5', sep=';', skiprows=[0,1])
    return dams

# %%
def make_gdf(df):
    '''
    Converts the dataframe to a geodaframe
    using the columns Longitude and Latitude
    ---
    Parameters:
    
    df -> The dam safety dataframe
    '''
    
    df['geometry'] = df.apply(lambda row: Point(row.longitude, row.latitude), axis=1)
    
    df = gpd.GeoDataFrame(df)
    
    return df

# %%
def crs_to_area(gdf):
    '''
    Converts the CRS for equal
    area calculations.
    ---
    Parameters:
    
    gdf -> A geodataframe
    '''
    
    return gdf.to_crs('''PROJCS["Brasil_Albers_Equal_Area",GEOGCS["GCS_WGS_1984",DATUM["D_SIRGAS_2000",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers"],PARAMETER["false_easting",5000000.0],PARAMETER["false_northing",10000000.0],PARAMETER["central_meridian",-54.0],PARAMETER["standard_parallel_1",-2.0],PARAMETER["standard_parallel_2",-22.0],PARAMETER["latitude_of_origin",-12.0],UNIT["Meter",1.0]]''')

# %%
def crs_to_coords(gdf):
    '''
    Converts the CRS of the geodataframe
    to the Brazilian standard for geogra-
    phic projections.
    ---
    Parameters:
    
    gdf -> A geodataframe
    '''
    
    return gdf.to_crs("EPSG:4674")

# %%
def standardize_columns(df):
    '''
    Remove special characters from the column
    names and makes them all lowercase. 
    ---
    Parameters:
    
    df -> The dam safety dataframe
    '''
    
    df.columns = df.columns.map(unidecode)
    df.columns = df.columns.map(lambda x: x.lower())
    df.columns = df.columns.map(lambda x: x.strip())
    
    return df

# %%
def fix_separators(df):
    '''
    The Latitude and Longitude columns in the dataframe
    are currently stored as strings with a ',' as the decimal
    separator. This function changes the separator to '.' and
    casts it to float.
    ---
    Parameters:
    
    df -> The dam safety dataframe
    '''
    
    df.latitude = df.latitude.str.replace(",", ".").astype(float)
    df.longitude = df.longitude.str.replace(",", ".").astype(float)
    df.capacidade_hm3 = df.capacidade_hm3.str.replace(",", ".").astype(float)
    
    return df

# %%
def classify_risky_dams(df):
    '''
    Marks the dams that have both a
    high risk category and a high
    potential damage so we can proceed 
    in the analysis.
    ---
    Parameters:
    
    df -> The dam safety dataframe
    '''
    
    condition = (df.categoria_de_risco == 'Alto') & (df.dano_potencial_associado == 'Alto')
    
    df['high_risk_high_damage'] = np.where(condition, True, False)
    
    return df

# %%
def create_buffer(gdf, r):
    '''
    Creates a buffer around the
    geometries of the given gdf
    with a r radius.
    '''
    
    gdf.geometry = gdf.geometry.buffer(r)
    
    return gdf

# %%
def get_dams():
    '''
    Runs all the functions to prepare
    the dam safety dataset sequentially.
    '''
    
    dams = read_dams()
    dams = standardize_columns(dams)
    dams = fix_separators(dams)
    dams = make_gdf(dams)
    dams = classify_risky_dams(dams)
    dams = dams[dams.high_risk_high_damage] # selects using boolean mask
    dams = dams.set_crs("EPSG:4674") # Brazilian standard projection
    dams = crs_to_area(dams)
    dams = create_buffer(dams, 1000)
    
    return dams

# %%
# Runs all the data reading/cleaning routines and save it to disk
# This takes some time to do, so let's save it on disk for further runs

### IN CASE THIS IS THE FIRST YOU ARE RUNNING THE SCRIPT,
### UNCOMMENT THE NEXT LINES 

#dangerous_dams = get_dams()
#dangerous_dams.to_feather("../../data/brazil/snisb/dangerous-dams.feather")

# %%
# Alternatively, read from disk to increase speed
dangerous_dams = gpd.read_feather("../../data/brazil/snisb/dangerous-dams.feather")

# %% [markdown]
# Let's also read the population grid.

# %%
# Reads file + converts CRS
grid = gpd.read_feather("../../data/brazil/grade/dasymetric-interpolation.feather")
grid = grid.to_crs(dangerous_dams.crs)

# %% [markdown]
# And both shapefiles and population counts for cities, states and regions.

# %%
### IN CASE THIS IS THE FIRST YOU ARE RUNNING THE SCRIPT,
### UNCOMMENT THE NEXT LINES 

# regions = geobr.read_region(2020)
# regions = regions.to_crs(grid.crs)
# regions_pop = pd.read_csv("../../data/brazil/pop/region.csv", sep=";")
# regions = regions.merge(regions_pop, left_on='code_region', right_on='code')
# regions.to_feather("../../data/brazil/geobr/regions.feather")

# states = geobr.read_state('all', 2020)
# states = states.to_crs(grid.crs)
# states_pop = pd.read_csv("../../data/brazil/pop/state.csv", sep=";")
# states = states.merge(states_pop, left_on='code_state', right_on='code')
# states.to_feather("../../data/brazil/geobr/states.to_feather")

# cities = geobr.read_municipality('all', 2020)
# cities['code_muni'] = cities.code_muni.astype(int).astype(str).str.slice(0, -1) # need to merge on the first 6 digits
# cities = cities.to_crs(grid.crs)
# cities_pop = pd.read_csv("../../data/brazil/pop/city.csv", sep=";", dtype={'code': str})
# cities = cities.merge(cities_pop, left_on='code_muni', right_on='code')
# cities.to_feather("../../data/brazil/geobr/cities.feather")

# %%
# # Alternatively, reads from disk to increase speed
regions = gpd.read_feather("../../data/brazil/geobr/regions.feather")
states = gpd.read_feather("../../data/brazil/geobr/states.feather")
cities = gpd.read_feather("../../data/brazil/geobr/cities.feather")

# %% [markdown]
# And we also need to select all the grid squares that are near at least one dangerous dam.

# %%
### IN CASE THIS IS THE FIRST YOU ARE RUNNING THE SCRIPT,
### UNCOMMENT THE NEXT LINES 

# # Spatial join will result in one line for each grid within a dam radius.
# # This means that we need to remove duplicate grid squares, which are nearby more than one dam

# grid_squares_near_dangerous_dams = gpd.sjoin(grid, dangerous_dams)
# grid_squares_near_dangerous_dams = grid_squares_near_dangerous_dams.drop_duplicates(subset='ID_UNICO').reset_index()
# grid_squares_near_dangerous_dams = grid_squares_near_dangerous_dams[
#                                                              # We keep only grid-relevant info
#                                                              ['ID_UNICO', 'QUADRANTE', 'MASC', 'FEM',
#                                                               'POP', 'DOM_OCU', 'pct_literate_residents',
#                                                               'pct_black_and_pardo_residents',
#                                                               'permanent_household_nominal_mean_income',
#                                                               'pct_private_households_under_minimum_wage',
#                                                               'geometry']
#                                                         ]
# grid_squares_near_dangerous_dams = grid_squares_near_dangerous_dams.to_feather(
#     "../../data/brazil/grade/squares-near-dangerous-dams.feather"
# )

# %%
# Alternatively, reads from disk
grid_squares_near_dangerous_dams = gpd.read_feather("../../data/brazil/grade/squares-near-dangerous-dams.feather")

# %% [markdown]
# #### Analysis

# %% [markdown]
# How many Brazilians live near dangerous dams?

# %%
# The simplest answer: the sum of the population living in the grid squares near dangerous dams
grid_squares_near_dangerous_dams.POP.sum()
# Out:
# 937649

# %% [markdown]
# How many Brazilians in each region live near dangerous dams?

# %%
def people_by_geo_group(grid_squares, geo_group, groupby_columns):
    '''
    This function computes how many people live near dangerous
    dam within a geographical division of Brazil: regions, states
    and cities.
    
    Note the following caveat: some grid squares fall in the border
    of different regions and doing adequate computations for those
    would be too much work for small difference. We will, then,
    simply attribute a region to each part of the grid and mantain
    the duplicates – the total sum could be slightly above the
    previous 937639, then, if a populated area near a dam is right
    on the edge of two different geographical regions.
    ---
    Parameters:
    
    grid_squares -> A geodaframe selection of geometries with the population
    that we want to count
    geo_group -> A geodataframe with the geometries representing the relevant
    geographic divisions.
    groupby_column -> Arrays representing columns in the geo_group geo-
    dataframe. It represents the unique ids for each of the geographic divisions
    for which we want to estimate population counts.
    '''

    return gpd.sjoin(grid_squares, geo_group) \
        .groupby(groupby_columns) \
        .POP \
        .sum() \
        .sort_values(ascending=False) \
        .to_frame() \
        .reset_index()

# %%
people_near_dams_by_region = people_by_geo_group(grid_squares_near_dangerous_dams, regions, ['code_region', 'name_region'])
display(people_near_dams_by_region)
# Out:
#    code_region   name_region     POP
# 0          2.0      Nordeste  562123
# 1          3.0       Sudeste  255433
# 2          1.0         Norte   82040
# 3          4.0           Sul   22905
# 4          5.0  Centro Oeste   15148

# %% [markdown]
# Let's repeat this for the states and cities.

# %%
people_near_dams_by_state = people_by_geo_group(grid_squares_near_dangerous_dams, states, ['code_state', 'name_state'])
display(people_near_dams_by_state)
# Out:
#     code_state           name_state     POP
# 0         26.0           Pernambuco  161531
# 1         29.0                Bahia  161061
# 2         24.0  Rio Grande Do Norte  133067
# 3         31.0         Minas Gerais   97722
# 4         35.0            São Paulo   84117
# 5         25.0              Paraíba   82713
# 6         15.0                 Pará   66372
# 7         33.0       Rio De Janeiro   38994
# 8         32.0       Espírito Santo   34600
# 9         41.0               Paraná   15009
# 10        51.0          Mato Grosso   14335
# 11        16.0                Amapá   13851
# 12        21.0             Maranhão   12699
# 13        42.0       Santa Catarina    7887
# 14        22.0                Piauí    7206
# 15        28.0              Sergipe    2067
# 16        27.0              Alagoas    1825
# 17        11.0             Rondônia    1111
# 18        23.0                Ceará     825
# 19        52.0                Goiás     813
# 20        14.0              Roraima     700
# 21        43.0    Rio Grande Do Sul       9
# 22        17.0            Tocantins       6

# %%
people_near_dams_by_city = people_by_geo_group(grid_squares_near_dangerous_dams, cities, ['code_muni', 'name_muni'])
display(people_near_dams_by_city.head(10))
# Out:
#   code_muni                name_muni    POP
# 0    310620           Belo Horizonte  86022
# 1    292740                 Salvador  40415
# 2    260790  Jaboatão Dos Guararapes  36842
# 3    260345               Camaragibe  21358
# 4    355240                   Sumaré  20987
# 5    330320                Nilópolis  18528
# 6    330285                 Mesquita  17252
# 7    150220                 Capanema  15654
# 8    352390                      Itu  15331
# 9    351620                   Franca  14610

# %% [markdown]
# How many people by 10,000 live near a dangerous dam in each region, state and city?

# %%
def per_capita_ratios(numerator_df, numerator_column, denominator_df, denominator_column, merge_column, ratio=1):
    '''
    Computes per capita ratios using one dataframe
    with values for the population that was subject
    to an event and one dataframe for the total
    population in the area.
    ---
    Parameters:
    
    numerator_df -> Dataframe representing the popu-
    lation in a given area that went through some event.
    
    numerator_column -> String representing the column name
    which countains the population values.
    
    denominator_df -> Dataframe representing the total
    population in a given area.
    
    denominator_column -> String representing the column name
    which countains the population values.
    
    merge_column -> String representing a common column between
    the two dataframes through which a merge will be performed.
    
    ratio -> Sets a multiplier for the ratio. e.g, if
    ratio == 10000, the result will show a ratio for each 10,000
    people. Defaults to 1.
    
    '''
    
    results = numerator_df.merge(denominator_df, on=merge_column, suffixes=["", "_y"])
    
    results = results.drop(columns=[col for col in results.columns if "_y" in col])
    
    results['ratio']= results[numerator_column] / results[denominator_column] * ratio

    # Renames columns to increase readability
    results = results.rename(columns={numerator_column: "people_near_dangerous_dams", 
                           denominator_column: "total_population",
                           "ratio": f"{ratio}_ratio"})
    
    results = results.sort_values(by=f"{ratio}_ratio", ascending=False) 
        
    return results

# %%
ratios_by_region = per_capita_ratios(people_near_dams_by_region, 'POP', regions, 'pop', 'code_region', 10000).reset_index()
ratios_by_region = gpd.GeoDataFrame(ratios_by_region) # cast to gdf to save as feather
ratios_by_region.to_feather("../../data/brazil/near-dam-ratios/pop-near-dangerous-dams-by-region.feather")
display(ratios_by_region.head(10))
# Out:
#    index  code_region   name_region  people_near_dangerous_dams  \
# 0      0          2.0      Nordeste                      562123
# 1      2          1.0         Norte                       82040
# 2      1          3.0       Sudeste                      255433
# 3      4          5.0  Centro Oeste                       15148
# 4      3          4.0           Sul                       22905
#
#                                             geometry  code  \
# 0  MULTIPOLYGON (((6605500.388 9801072.213, 66053...     2
# 1  MULTIPOLYGON (((5844252.032 11213965.446, 5844...     1
# 2  MULTIPOLYGON (((5607810.407 8505662.544, 56077...     3
# 3  MULTIPOLYGON (((4602519.086 8997067.676, 46014...     5
# 4  MULTIPOLYGON (((5188736.426 7819178.176, 51888...     4
#
#                 region  total_population  10000_ratio
# 0      Região Nordeste          53081950   105.897202
# 1         Região Norte          15864454    51.713094
# 2       Região Sudeste          80364410    31.784343
# 3  Região Centro-Oeste          14058094    10.775287
# 4           Região Sul          27386891     8.363490

# %%
ratios_by_state = per_capita_ratios(people_near_dams_by_state, 'POP', states, 'pop', 'code_state', 10000).reset_index()
ratios_by_state = gpd.GeoDataFrame(ratios_by_state) # cast to gdf to save as feather
ratios_by_state.to_feather("../../data/brazil/near-dam-ratios/pop-near-dangerous-dams-by-state.feather")
display(ratios_by_state.head(10))
# Out:
#    index  code_state           name_state  people_near_dangerous_dams  \
# 0      2        24.0  Rio Grande Do Norte                      133067
# 1      5        25.0              Paraíba                       82713
# 2     11        16.0                Amapá                       13851
# 3      0        26.0           Pernambuco                      161531
# 4      1        29.0                Bahia                      161061
# 5      8        32.0       Espírito Santo                       34600
# 6      6        15.0                 Pará                       66372
# 7      3        31.0         Minas Gerais                       97722
# 8     10        51.0          Mato Grosso                       14335
# 9      7        33.0       Rio De Janeiro                       38994
#
#   abbrev_state  code_region   name_region  \
# 0           RN          2.0      Nordeste
# 1           PB          2.0      Nordeste
# 2           AP          1.0         Norte
# 3           PE          2.0      Nordeste
# 4           BA          2.0      Nordeste
# 5           ES          3.0       Sudeste
# 6           PA          1.0         Norte
# 7           MG          3.0       Sudeste
# 8           MT          5.0  Centro Oeste
# 9           RJ          3.0       Sudeste
#
#                                             geometry  code  \
# 0  MULTIPOLYGON (((6866272.431 10747646.115, 6866...    24
# 1  MULTIPOLYGON (((7093988.192 10449669.249, 7093...    25
# 2  MULTIPOLYGON (((5400648.179 11565814.635, 5400...    16
# 3  MULTIPOLYGON (((7385901.887 10822712.549, 7385...    26
# 4  MULTIPOLYGON (((6603991.385 9285519.506, 66039...    29
# 5  MULTIPOLYGON (((6373149.038 8968278.041, 63731...    32
# 6  MULTIPOLYGON (((5287183.770 11284166.374, 5287...    15
# 7  MULTIPOLYGON (((5340197.797 9189607.243, 53402...    31
# 8  MULTIPOLYGON (((4185288.338 10213558.205, 4185...    51
# 9  MULTIPOLYGON (((6252609.806 8767805.232, 62525...    33
#
#                 state"  total_population  10000_ratio
# 0  Rio Grande do Norte           3168027   420.031142
# 1              Paraíba           3766528   219.600120
# 2                Amapá            669526   206.877702
# 3           Pernambuco           8796448   183.632075
# 4                Bahia          14016906   114.904816
# 5       Espírito Santo           3514952    98.436622
# 6                 Pará           7581051    87.549866
# 7         Minas Gerais          19597330    49.864956
# 8          Mato Grosso           3035122    47.230391
# 9       Rio de Janeiro          15989929    24.386600

# %%
ratios_by_city = per_capita_ratios(people_near_dams_by_city, 'POP', cities, 'pop', 'code_muni', 10000).reset_index()
ratios_by_city = gpd.GeoDataFrame(ratios_by_city) # cast to gdf to save as feather
ratios_by_city.to_feather("../../data/brazil/near-dam-ratios/pop-near-dangerous-dams-by-city.feather")
display(ratios_by_city.head(10))
# Out:
#    index code_muni                  name_muni  people_near_dangerous_dams  \
# 0    109    240480                    Ipueira                        1954
# 1     86    241070             Riacho Da Cruz                        2564
# 2     23    240080                    Angicos                        9151
# 3     29    240010                      Acari                        7637
# 4    108    240390           Francisco Dantas                        1966
# 5    152    251465  São José Do Brejo Do Cruz                        1145
# 6    106    241060             Rafael Godeiro                        2056
# 7     92    240690                   Lucrécia                        2402
# 8     45    260360                  Camutanga                        5199
# 9    103    241180               São Fernando                        2111
#
#    code_state abbrev_state           name_state  code_region name_region  \
# 0        24.0           RN  Rio Grande do Norte          2.0    Nordeste
# 1        24.0           RN  Rio Grande do Norte          2.0    Nordeste
# 2        24.0           RN  Rio Grande do Norte          2.0    Nordeste
# 3        24.0           RN  Rio Grande do Norte          2.0    Nordeste
# 4        24.0           RN  Rio Grande do Norte          2.0    Nordeste
# 5        25.0           PB              Paraíba          2.0    Nordeste
# 6        24.0           RN  Rio Grande do Norte          2.0    Nordeste
# 7        24.0           RN  Rio Grande do Norte          2.0    Nordeste
# 8        26.0           PE           Pernambuco          2.0    Nordeste
# 9        24.0           RN  Rio Grande do Norte          2.0    Nordeste
#
#                                             geometry    code  \
# 0  MULTIPOLYGON (((6848618.181 10535019.964, 6849...  240480
# 1  MULTIPOLYGON (((6763689.827 10637953.559, 6763...  241070
# 2  MULTIPOLYGON (((6912766.151 10659082.738, 6923...  240080
# 3  MULTIPOLYGON (((6901921.669 10583120.553, 6901...  240010
# 4  MULTIPOLYGON (((6740766.793 10627397.517, 6741...  240390
# 5  MULTIPOLYGON (((6825231.612 10599178.200, 6825...  251465
# 6  MULTIPOLYGON (((6779484.019 10620233.187, 6781...  241060
# 7  MULTIPOLYGON (((6775636.032 10610236.184, 6775...  240690
# 8  MULTIPOLYGON (((7041664.845 10447122.995, 7041...  260360
# 9  MULTIPOLYGON (((6846500.010 10596368.761, 6846...  241180
#
#                         city  total_population  10000_ratio
# 0                    Ipueira              2077  9407.799711
# 1             Riacho da Cruz              3165  8101.105845
# 2                    Angicos             11549  7923.629751
# 3                      Acari             11035  6920.706842
# 4           Francisco Dantas              2874  6840.640223
# 5  São José do Brejo do Cruz              1684  6799.287411
# 6             Rafael Godeiro              3063  6712.373490
# 7                   Lucrécia              3633  6611.615745
# 8                  Camutanga              8156  6374.448259
# 9               São Fernando              3401  6206.997942

# %% [markdown]
# What are those dangerous dams used for?

# %%
dangerous_dams.uso_principal.value_counts()
# Out:
# Abastecimento humano                  505
# Irrigação                             254
# Regularização de vazão                119
# Dessedentação Animal                  111
# Aquicultura                            65
# Recreação                              42
# Contenção de rejeitos de mineração     39
# Industrial                             33
# Combate às secas                       28
# Contenção de resíduos industriais       9
# Defesa contra inundações                9
# Paisagismo                              5
# Proteção do meio ambiente               1
# Name: uso_principal, dtype: int64

# %% [markdown]
# Are the main uses different if we segment by state and region?

# %%
dangerous_dams[dangerous_dams.uso_principal=='Irrigação'].uf.value_counts(normalize=True)
# Out:
# BA    0.248031
# ES    0.145669
# PB    0.141732
# PA    0.133858
# GO    0.110236
# PE    0.090551
# RN    0.043307
# AL    0.031496
# MT    0.023622
# TO    0.011811
# RS    0.007874
# MG    0.003937
# PI    0.003937
# SE    0.003937
# Name: uf, dtype: float64

# %%
dangerous_dams[dangerous_dams.uso_principal=='Abastecimento humano'].uf.value_counts(normalize=True)
# Out:
# RN    0.249505
# PB    0.245545
# BA    0.241584
# PE    0.198020
# PI    0.013861
# ES    0.009901
# SP    0.009901
# MT    0.005941
# SE    0.003960
# CE    0.003960
# PA    0.003960
# GO    0.003960
# MG    0.003960
# RJ    0.001980
# PR    0.001980
# RR    0.001980
# Name: uf, dtype: float64

# %% [markdown]
# Which dams affect, alone, the most people?

# %%
# For each dam, select all the grid squares that intersect it
# sum the population, then order by most people affected. Notice that this
# will only keep dams that have people living in the 1km
# radius around it, excluding all others
dangerous_dams_pop = gpd.sjoin(dangerous_dams, grid_squares_near_dangerous_dams) \
    .groupby(["codigo_snisb"]) \
    .POP \
    .sum() \
    .reset_index()\
    .merge(dangerous_dams, on='codigo_snisb')\
    .rename(columns={"POP":"affected_population"})\
    .sort_values(by='affected_population', ascending=False)\
    .reset_index()

dangerous_dams_pop = gpd.GeoDataFrame(dangerous_dams_pop)
dangerous_dams_pop.to_feather("../../data/brazil/snisb/dangerous-dams-population.feather")

# %% [markdown]
# Looking at the two cities that have the higher percentage of population living near dams.

# %%
dangerous_dams_pop[dangerous_dams_pop.municipio=="IPUEIRA"]
# Out:
#       index  codigo_snisb  affected_population           nome_da_barragem  \
# 114     814         18142                 1916  Barragem do Sítio Ipueira
# 898     609          7589                   20            CURRAL QUEIMADO
# 954     596          7575                   14                  CARNAÚBAS
# 1055    598          7578                    5                     JATAHÍ
#
#      nome_secundario         uso_principal  uf municipio categoria_de_risco  \
# 114             None  Dessedentação Animal  RN   IPUEIRA               Alto
# 898             None  Abastecimento humano  RN   IPUEIRA               Alto
# 954             None  Abastecimento humano  RN   IPUEIRA               Alto
# 1055            None  Abastecimento humano  RN   IPUEIRA               Alto
#
#      dano_potencial_associado  ... data_da_ultima_inspecao  \
# 114                      Alto  ...                    None
# 898                      Alto  ...                    None
# 954                      Alto  ...                    None
# 1055                     Alto  ...                    None
#
#      tipo_da_ultima_inspecao nivel_de_perigo_global possui_eclusa  \
# 114                     None                   None          None
# 898                     None                   None          None
# 954                     None                   None          None
# 1055                    None                   None          None
#
#      fase_da_vida latitude longitude completude  \
# 114          None -6.81528 -37.19333      baixa
# 898          None -6.77522 -37.19868      baixa
# 954          None -6.76747 -37.25097     mínima
# 1055         None -6.74941 -37.24768     mínima
#
#                                                geometry high_risk_high_damage
# 114   POLYGON ((6837490.411 10526197.929, 6837485.59...                  True
# 898   POLYGON ((6837175.329 10530703.712, 6837170.51...                  True
# 954   POLYGON ((6831519.365 10531911.253, 6831514.54...                  True
# 1055  POLYGON ((6831999.331 10533905.107, 6831994.51...                  True
#
# [4 rows x 41 columns]

# %%
dangerous_dams_pop[dangerous_dams_pop.municipio=="RIACHO DA CRUZ"]
# Out:
#     index  codigo_snisb  affected_population   nome_da_barragem  \
# 88    481          7435                 2564  RIACHO DA CRUZ II
#
#    nome_secundario         uso_principal  uf       municipio  \
# 88            None  Abastecimento humano  RN  RIACHO DA CRUZ
#
#    categoria_de_risco dano_potencial_associado  ... data_da_ultima_inspecao  \
# 88               Alto                     Alto  ...                    None
#
#    tipo_da_ultima_inspecao nivel_de_perigo_global possui_eclusa fase_da_vida  \
# 88                    None                   None          None         None
#
#    latitude longitude completude  \
# 88 -5.93751 -37.94027      baixa
#
#                                              geometry high_risk_high_damage
# 88  POLYGON ((6761589.351 10628896.079, 6761584.53...                  True
#
# [1 rows x 41 columns]

# %% [markdown]
# The sate of Amapá is particularly interesting: it has a high share of people affected by dangerous dams, but it's not in the Northeast, but in the Amazon – no reason for anti-drought dams there. What is going on?

# %%
dangerous_dams_pop[dangerous_dams_pop.uf=="AP"]
# Out:
#      index  codigo_snisb  affected_population  nome_da_barragem  \
# 11     921         20277                13309  Açude do Zezinho
# 225    182          3962                  542       PANASQUEIRA
#
#     nome_secundario uso_principal  uf        municipio categoria_de_risco  \
# 11             None     Recreação  AP           MACAPÁ               Alto
# 225            None   Aquicultura  AP  TARTARUGALZINHO               Alto
#
#     dano_potencial_associado  ... data_da_ultima_inspecao  \
# 11                      Alto  ...              25-11-2019
# 225                     Alto  ...              26-11-2019
#
#     tipo_da_ultima_inspecao nivel_de_perigo_global possui_eclusa fase_da_vida  \
# 11                  Regular                   None           Não         None
# 225                 Regular                   None           Não         None
#
#     latitude longitude completude  \
# 11   0.04428 -51.07210     mínima
# 225  1.57747 -50.90803      ótima
#
#                                               geometry high_risk_high_damage
# 11   POLYGON ((5329087.323 11340677.182, 5329082.50...                  True
# 225  POLYGON ((5349327.676 11508412.718, 5349322.86...                  True
#
# [2 rows x 41 columns]

# %% [markdown]
# It appears to be simply scarcely populated with a single, big, dangerous dam in the capital.

# %% [markdown]
# Ok, but what about the mining dams - how many people live near them?

# %%
dangerous_dams_pop[dangerous_dams_pop.uso_principal=="Contenção de rejeitos de mineração"].affected_population.sum()
# Out:
# 1169

# %% [markdown]
# Let's look at their details.

# %%
dangerous_dams_pop[dangerous_dams_pop.uso_principal=="Contenção de rejeitos de mineração"]
# Out:
#       index  codigo_snisb  affected_population          nome_da_barragem  \
# 218      59           943                  574                    Doutor
# 486      58           835                  129              Sul Inferior
# 623     950         20417                   75              Capim Branco
# 640     265          6989                   69             Maravilhas II
# 674      53           702                   59                     B3/B4
# 701      54           721                   52             Borrachudo II
# 728      51           622                   46                5 (Mutuca)
# 774      56           742                   36         Norte/Laranjeiras
# 881      55           734                   22  Barragem II Mina Engenho
# 889    1047         26137                   20           Barragem Quéias
# 917      57           820                   18                   Santana
# 922      61          1121                   17     Barragem Mina Engenho
# 961      52           690                   14          Barragem B1A Ipê
# 990     266          7007                   12                Água Fria
# 999     204          5563                   11               Santa Maria
# 1040    263          6976                    7             Santa Bárbara
# 1059     63          1208                    5               Barragem 01
# 1078     60          1024                    3            Barragem B1/B4
#
#      nome_secundario                       uso_principal  uf  \
# 218             None  Contenção de rejeitos de mineração  MG
# 486             None  Contenção de rejeitos de mineração  MG
# 623             None  Contenção de rejeitos de mineração  MG
# 640             None  Contenção de rejeitos de mineração  MG
# 674             None  Contenção de rejeitos de mineração  MG
# 701             None  Contenção de rejeitos de mineração  MG
# 728             None  Contenção de rejeitos de mineração  MG
# 774             None  Contenção de rejeitos de mineração  MG
# 881             None  Contenção de rejeitos de mineração  MG
# 889             None  Contenção de rejeitos de mineração  MG
# 917             None  Contenção de rejeitos de mineração  MG
# 922             None  Contenção de rejeitos de mineração  MG
# 961             None  Contenção de rejeitos de mineração  MG
# 990             None  Contenção de rejeitos de mineração  MG
# 999             None  Contenção de rejeitos de mineração  MT
# 1040            None  Contenção de rejeitos de mineração  MG
# 1059            None  Contenção de rejeitos de mineração  BA
# 1078            None  Contenção de rejeitos de mineração  MG
#
#                         municipio categoria_de_risco dano_potencial_associado  \
# 218                    OURO PRETO               Alto                     Alto
# 486               BARÃO DE COCAIS               Alto                     Alto
# 623                    BRUMADINHO               Alto                     Alto
# 640                     ITABIRITO               Alto                     Alto
# 674                     NOVA LIMA               Alto                     Alto
# 701                       ITABIRA               Alto                     Alto
# 728                     NOVA LIMA               Alto                     Alto
# 774               BARÃO DE COCAIS               Alto                     Alto
# 881                     RIO ACIMA               Alto                     Alto
# 889                    BRUMADINHO               Alto                     Alto
# 917                       ITABIRA               Alto                     Alto
# 922                     RIO ACIMA               Alto                     Alto
# 961                    BRUMADINHO               Alto                     Alto
# 990                    OURO PRETO               Alto                     Alto
# 999   NOSSA SENHORA DO LIVRAMENTO               Alto                     Alto
# 1040                   BRUMADINHO               Alto                     Alto
# 1059                  MAIQUINIQUE               Alto                     Alto
# 1078                        ARAXÁ               Alto                     Alto
#
#       ... data_da_ultima_inspecao tipo_da_ultima_inspecao  \
# 218   ...                    None                    None
# 486   ...                    None                    None
# 623   ...                    None                    None
# 640   ...                    None                    None
# 674   ...              16-12-2019                 Regular
# 701   ...                    None                    None
# 728   ...              26-12-2019                 Regular
# 774   ...                    None                    None
# 881   ...                    None                    None
# 889   ...                    None                    None
# 917   ...                    None                    None
# 922   ...                    None                    None
# 961   ...                    None                    None
# 990   ...                    None                    None
# 999   ...              26-12-2019                 Regular
# 1040  ...              27-12-2019                 Regular
# 1059  ...              29-12-2019                 Regular
# 1078  ...              17-12-2019                 Regular
#
#      nivel_de_perigo_global possui_eclusa fase_da_vida  latitude longitude  \
# 218                    None          None      Inativa -20.29111 -43.49056
# 486                    None          None         None -19.97556 -43.60056
# 623                    None          None         None -20.10828 -44.07367
# 640                    None          None         None -20.21442 -43.89169
# 674                    None          None         None -20.04722 -43.95361
# 701                    None          None         None -19.61250 -43.26667
# 728                    None          None      Inativa -20.02611 -43.94250
# 774                    None          None         None -19.84833 -43.42167
# 881                    None          None         None -20.06278 -43.79472
# 889                    None          None      Inativa -20.12697 -44.31608
# 917                    None          None         None -19.55500 -43.16056
# 922                    None          None         None -20.06167 -43.79444
# 961                    None          None         None -20.12278 -44.31250
# 990                    None          None         None -20.44741 -43.64382
# 999                    None          None         None -15.64796 -56.38134
# 1040                   None          None         None -20.16186 -44.00622
# 1059                   None          None         None -15.77814 -40.32097
# 1078                   None          None         None -19.63361 -46.99694
#
#      completude                                           geometry  \
# 218         boa  POLYGON ((6093096.386 9050994.992, 6093091.571...
# 486         boa  POLYGON ((6082976.163 9086517.775, 6082971.348...
# 623       baixa  POLYGON ((6033249.987 9073540.601, 6033245.172...
# 640       baixa  POLYGON ((6051739.410 9061058.374, 6051734.595...
# 674         boa  POLYGON ((6045973.850 9079887.279, 6045969.034...
# 701         boa  POLYGON ((6119249.058 9125616.002, 6119244.243...
# 728         boa  POLYGON ((6047213.425 9082194.276, 6047208.610...
# 774         boa  POLYGON ((6102114.995 9099977.690, 6102110.180...
# 881         boa  POLYGON ((6062430.324 9077558.123, 6062425.509...
# 889       baixa  POLYGON ((6007979.706 9072345.149, 6007974.891...
# 917         boa  POLYGON ((6130546.808 9131592.761, 6130541.993...
# 922         boa  POLYGON ((6062463.940 9077680.540, 6062459.125...
# 961         boa  POLYGON ((6008367.968 9072798.327, 6008363.153...
# 990       baixa  POLYGON ((6076534.141 9034215.134, 6076529.326...
# 999       baixa  POLYGON ((4749068.802 9589374.933, 4749063.986...
# 1040      baixa  POLYGON ((6040048.231 9067331.388, 6040043.416...
# 1059        boa  POLYGON ((6446885.038 9540492.894, 6446880.222...
# 1078        boa  POLYGON ((5730655.830 9135584.985, 5730651.015...
#
#      high_risk_high_damage
# 218                   True
# 486                   True
# 623                   True
# 640                   True
# 674                   True
# 701                   True
# 728                   True
# 774                   True
# 881                   True
# 889                   True
# 917                   True
# 922                   True
# 961                   True
# 990                   True
# 999                   True
# 1040                  True
# 1059                  True
# 1078                  True
#
# [18 rows x 41 columns]

# %% [markdown]
# Do they have emergency plans?

# %%
dangerous_dams_pop[dangerous_dams_pop.uso_principal=="Contenção de rejeitos de mineração"].possui_pae.value_counts(normalize=True)
# Out:
# Sim    0.588235
# Não    0.411765
# Name: possui_pae, dtype: float64

# %% [markdown]
# And safety plans?

# %%
dangerous_dams_pop[dangerous_dams_pop.uso_principal=="Contenção de rejeitos de mineração"].possui_plano_de_seguranassa.value_counts(normalize=True)
# Out:
# Sim    0.944444
# Não    0.055556
# Name: possui_plano_de_seguranassa, dtype: float64

# %% [markdown]
# Let's load detailed data from another governing body – the National Mining Agency (Agência Nacional de Mineração, ANM) – notice that the dams don't use the same code, although the ANM data is a primary source for the other dataset. Some of the information shown in the datasets differs, possibly because they were extracted in different points in time, but the big picture remains the same: 30~40 dangerous mining dams.

# %%
anm = pd.read_excel("../../data/brazil/mining-dams/14032022-mining-dams-anm.xlsx")

# %%
anm[(anm['Categoria de Risco']=='Alto') & 
    (anm['Dano Potencial Associado']=='Alto') & 
    (anm['ID Barragem'].astype(str).isin(dangerous_dams.codigo_barragem_fiscalizador))].shape
# Out:
# (32, 19)

# %% [markdown]
# What about the dams built by the DNOCS?

# %%
dangerous_dams_pop[dangerous_dams_pop.nome_do_empreendedor=="Departamento Nacional de Obras Contra as Secas"]
# Out:
#       index  codigo_snisb  affected_population          nome_da_barragem  \
# 13      740          7780                13101      SANTA CRUZ DO TRAIRI
# 21      708          7724                 9374             CURRAIS NOVOS
# 35      377          7233                 6480          Juraci Magalhães
# 36      661          7656                 6391                    Mororó
# 83      396          7277                 2682                Parnamirim
# 88      481          7435                 2564         RIACHO DA CRUZ II
# 106     698          7706                 2196            Serra Branca I
# 110     469          7411                 1966                   TESOURA
# 123     456          7382                 1767               São Gonçalo
# 124     984         21420                 1763                Tamboril I
# 138     982         21417                 1530                      Pati
# 144     744          7788                 1444  Malhada da Pedra (Açude)
# 175     663          7659                 1059                      Sumé
# 176     287          7063                 1020               BENEDITIONS
# 184     763          7815                  881     Vertente do Heráclito
# 194     521          7487                  798      Engenheiro Arcoverde
# 206     713          7739                  686      Eng. Severino Guerra
# 227     719          7750                  533                  Soledade
# 247     383          7244                  440               Tamboril II
# 259     737          7777                  415         Serra dos Cavalos
# 287     311          7109                  356                    ANAJÁS
# 297     739          7779                  338         Guilherme Azevedo
# 307     381          7242                  315                   Saco II
# 316     656          7650                  301                 Arcoverde
# 331     366          7214                  271                 Araripina
# 333     711          7731                  264                  Mundau I
# 346     542          7512                  247                   Rosário
# 353     286          7062                  235                  Tábua II
# 358     188          4038                  228           Barragem Pilões
# 361     741          7781                  226                    INHARÉ
# 375     424          7323                  209                 Boa Vista
# 378     412          7300                  206                   Cariacá
# 380     199          5241                  205                   Delfino
# 429     757          7805                  160                 Jucazinho
# 431     803          8632                  159               São Caetano
# 460     444          7360                  144                  Serrinha
# 475     519          7485                  134                  Custódia
# 479     479          7433                  130                  CORREDOR
# 485     457          7385                  129              Cachoeira II
# 499     464          7397                  120                   FLECHAS
# 513     328          7137                  114         Tancão do Caititu
# 525     436          7345                  107                  Arrodeio
# 534     432          7336                  105                    Saco I
# 572     389          7260                   92               Entremontes
# 661     583          7561                   62                     Barra
# 738     689          7694                   45               ZANGARELHAS
# 748     762          7814                   44             Bonito Grande
# 773     981         21416                   37                  Cruzeiro
# 796     406          7293                   33                  Abóboras
# 861     452          7373                   24         Firmino (Galante)
# 885     638          7626                   21                MUNDO NOVO
# 887     652          7646                   21                    Poções
# 913     731          7768                   18                 São Pedro
# 924     727          7764                   17   Riacho de Santo Antônio
# 1026    426          7326                    8                 Salgueiro
#
#         nome_secundario           uso_principal  uf                 municipio  \
# 13                 None    Abastecimento humano  RN                SANTA CRUZ
# 21                 None               Irrigação  RN             CURRAIS NOVOS
# 35        Poço do Urubu    Abastecimento humano  BA                 ITABERABA
# 36                 None    Abastecimento humano  PE                     PEDRA
# 83                 None        Combate às secas  PE                PARNAMIRIM
# 88                 None    Abastecimento humano  RN            RIACHO DA CRUZ
# 106                None    Abastecimento humano  PB              SERRA BRANCA
# 110                None    Abastecimento humano  RN          FRANCISCO DANTAS
# 123                None    Abastecimento humano  PB                     SOUSA
# 124                None    Abastecimento humano  PE                 ARCOVERDE
# 138                None        Combate às secas  PE                  OURICURI
# 144                None  Regularização de vazão  PE                   CARUARU
# 175                None    Abastecimento humano  PB                      SUMÉ
# 176         BENEDITINOS    Abastecimento humano  PI               BENEDITINOS
# 184                None    Abastecimento humano  PE                     OROBÓ
# 194                None    Abastecimento humano  PB                   CONDADO
# 206              Bituri        Combate às secas  PE               BELO JARDIM
# 227                None    Abastecimento humano  PB                  SOLEDADE
# 247        Eng. Camacho        Combate às secas  PE                  OURICURI
# 259      Antonio Menino    Abastecimento humano  PE                   CARUARU
# 287              ANAJÁS             Aquicultura  PI                  PIRIPIRI
# 297                None    Abastecimento humano  PE                   CARUARU
# 307                None        Combate às secas  PE  SANTA MARIA DA BOA VISTA
# 316       Riacho do Pau    Abastecimento humano  PE                     PEDRA
# 331              Baixio        Combate às secas  PE                 ARARIPINA
# 333           Garanhuns    Abastecimento humano  PE                 GARANHUNS
# 346                None    Abastecimento humano  PE                  IGUARACY
# 353                None    Abastecimento humano  BA                 IBIASSUCÊ
# 358                None    Abastecimento humano  PB  SÃO JOÃO DO RIO DO PEIXE
# 361              ALÍVIO    Abastecimento humano  RN                SANTA CRUZ
# 375                None               Irrigação  PE                 SALGUEIRO
# 378                None    Abastecimento humano  BA               MONTE SANTO
# 380                None    Dessedentação Animal  BA                 UMBURANAS
# 429                None    Abastecimento humano  PE                   SURUBIM
# 431   Brejo dos Coelhos    Abastecimento humano  PE               SÃO CAITANO
# 460         Serrinha II  Regularização de vazão  PE             SERRA TALHADA
# 475            Marrecas    Abastecimento humano  PE                  CUSTÓDIA
# 479                None    Abastecimento humano  RN           ANTÔNIO MARTINS
# 485                None    Abastecimento humano  PE             SERRA TALHADA
# 499                None    Abastecimento humano  RN             JOSÉ DA PENHA
# 513                None    Abastecimento humano  BA                  TREMEDAL
# 525                None        Combate às secas  PE      SÃO JOSÉ DO BELMONTE
# 534                None        Combate às secas  PE             SERRA TALHADA
# 572                None               Irrigação  PE                PARNAMIRIM
# 661                None    Abastecimento humano  PE                  SERTÂNIA
# 738                None    Dessedentação Animal  RN          JARDIM DO SERIDÓ
# 748                None    Abastecimento humano  PE        BARRA DE GUABIRABA
# 773                None    Abastecimento humano  PE      SÃO JOSÉ DO BELMONTE
# 796                None    Abastecimento humano  PE                PARNAMIRIM
# 861                None    Abastecimento humano  PB      SÃO JOSÉ DE PIRANHAS
# 885                None    Dessedentação Animal  RN                     CAICÓ
# 887                None    Abastecimento humano  PB                  MONTEIRO
# 913                None    Abastecimento humano  PB            CAMPINA GRANDE
# 924                None    Abastecimento humano  PB       BARRA DE SÃO MIGUEL
# 1026               None               Irrigação  PE                VERDEJANTE
#
#      categoria_de_risco dano_potencial_associado  ... data_da_ultima_inspecao  \
# 13                 Alto                     Alto  ...                    None
# 21                 Alto                     Alto  ...                    None
# 35                 Alto                     Alto  ...              26-08-2021
# 36                 Alto                     Alto  ...                    None
# 83                 Alto                     Alto  ...                    None
# 88                 Alto                     Alto  ...                    None
# 106                Alto                     Alto  ...                    None
# 110                Alto                     Alto  ...                    None
# 123                Alto                     Alto  ...                    None
# 124                Alto                     Alto  ...                    None
# 138                Alto                     Alto  ...                    None
# 144                Alto                     Alto  ...              09-03-2021
# 175                Alto                     Alto  ...                    None
# 176                Alto                     Alto  ...                    None
# 184                Alto                     Alto  ...              12-03-2021
# 194                Alto                     Alto  ...                    None
# 206                Alto                     Alto  ...                    None
# 227                Alto                     Alto  ...                    None
# 247                Alto                     Alto  ...                    None
# 259                Alto                     Alto  ...                    None
# 287                Alto                     Alto  ...                    None
# 297                Alto                     Alto  ...              06-03-2021
# 307                Alto                     Alto  ...                    None
# 316                Alto                     Alto  ...              11-11-2015
# 331                Alto                     Alto  ...                    None
# 333                Alto                     Alto  ...                    None
# 346                Alto                     Alto  ...                    None
# 353                Alto                     Alto  ...              10-11-2021
# 358                Alto                     Alto  ...                    None
# 361                Alto                     Alto  ...                    None
# 375                Alto                     Alto  ...                    None
# 378                Alto                     Alto  ...              10-09-2021
# 380                Alto                     Alto  ...              28-08-2021
# 429                Alto                     Alto  ...              10-03-2021
# 431                Alto                     Alto  ...              11-03-2021
# 460                Alto                     Alto  ...              28-02-2021
# 475                Alto                     Alto  ...                    None
# 479                Alto                     Alto  ...                    None
# 485                Alto                     Alto  ...              01-03-2021
# 499                Alto                     Alto  ...                    None
# 513                Alto                     Alto  ...              09-11-2021
# 525                Alto                     Alto  ...              03-03-2021
# 534                Alto                     Alto  ...              01-03-2021
# 572                Alto                     Alto  ...              03-03-2021
# 661                Alto                     Alto  ...                    None
# 738                Alto                     Alto  ...                    None
# 748                Alto                     Alto  ...              11-03-2021
# 773                Alto                     Alto  ...                    None
# 796                Alto                     Alto  ...              28-02-2021
# 861                Alto                     Alto  ...                    None
# 885                Alto                     Alto  ...                    None
# 887                Alto                     Alto  ...                    None
# 913                Alto                     Alto  ...                    None
# 924                Alto                     Alto  ...                    None
# 1026               Alto                     Alto  ...                    None
#
#      tipo_da_ultima_inspecao nivel_de_perigo_global possui_eclusa  \
# 13                      None                   None          None
# 21                      None                   None          None
# 35                   Regular                 Normal          None
# 36                      None                   None          None
# 83                      None                   None          None
# 88                      None                   None          None
# 106                     None                   None          None
# 110                     None                   None          None
# 123                     None                   None          None
# 124                     None                   None           Não
# 138                     None                   None           Não
# 144                  Regular                 Alerta          None
# 175                     None                   None          None
# 176                     None                   None          None
# 184                  Regular                 Alerta          None
# 194                     None                   None          None
# 206                     None                   None          None
# 227                     None                   None          None
# 247                     None                   None          None
# 259                     None                   None          None
# 287                     None                   None          None
# 297                  Regular                 Alerta          None
# 307                     None                   None          None
# 316                  Regular                   None          None
# 331                     None                   None          None
# 333                     None                   None          None
# 346                     None                   None          None
# 353                  Regular                 Normal          None
# 358                     None                   None          None
# 361                     None                   None          None
# 375                     None                   None          None
# 378                  Regular                 Normal          None
# 380                  Regular                Atenção           Não
# 429                  Regular                Atenção          None
# 431                  Regular                 Alerta          None
# 460                  Regular                 Alerta          None
# 475                     None                   None          None
# 479                     None                   None          None
# 485                  Regular                 Alerta          None
# 499                     None                   None          None
# 513                  Regular                 Normal          None
# 525                  Regular                Atenção          None
# 534                  Regular                Atenção          None
# 572                  Regular                 Alerta          None
# 661                     None                   None          None
# 738                     None                   None          None
# 748                  Regular                Atenção          None
# 773                     None                   None           Não
# 796                  Regular                 Alerta          None
# 861                     None                   None          None
# 885                     None                   None          None
# 887                     None                   None          None
# 913                     None                   None          None
# 924                     None                   None          None
# 1026                    None                   None          None
#
#      fase_da_vida  latitude longitude completude  \
# 13           None  -6.22450 -36.03037      baixa
# 21           None  -6.26901 -36.52645      baixa
# 35           None -12.53639 -40.31667      baixa
# 36           None  -8.49439 -36.94519        boa
# 83           None  -8.09203 -39.56758        boa
# 88           None  -5.93751 -37.94027      baixa
# 106          None  -7.47141 -36.66740      baixa
# 110          None  -6.08363 -38.12487      baixa
# 123          None  -6.84569 -38.31147      baixa
# 124          None  -8.43083 -37.04667      baixa
# 138          None  -7.81333 -40.16667      baixa
# 144      Operação  -8.24800 -35.91605      ótima
# 175          None  -7.67194 -36.89994        boa
# 176          None  -5.44260 -42.36430      baixa
# 184          None  -7.71675 -35.67561      ótima
# 194          None  -6.90825 -37.58908      baixa
# 206          None  -8.31086 -36.42592      baixa
# 227          None  -7.06961 -36.34636      baixa
# 247          None  -7.89639 -40.14972        boa
# 259          None  -8.36008 -36.04139      baixa
# 287          None  -4.24890 -41.78140      baixa
# 297          None  -8.36036 -36.03189      baixa
# 307          None  -8.54394 -40.16858      baixa
# 316          None  -8.55892 -36.98781      ótima
# 331          None  -7.57675 -40.47242        boa
# 333          None  -8.94592 -36.49183        boa
# 346          None  -7.77703 -37.47206        boa
# 353          None -14.33492 -42.37972      baixa
# 358          None  -6.68472 -38.52078        boa
# 361          None  -6.19470 -36.01985      baixa
# 375          None  -8.06108 -39.05297      baixa
# 378      Operação -10.48667 -39.35583      baixa
# 380      Operação -10.45972 -41.22361      baixa
# 429          None  -7.96631 -35.74231      baixa
# 431          None  -8.38639 -36.07256      ótima
# 460      Operação  -8.20851 -38.53320      baixa
# 475          None  -8.07631 -37.59789        boa
# 479          None  -6.18946 -37.95308      baixa
# 485          None  -7.97417 -38.32244      baixa
# 499          None  -6.30442 -38.24958      baixa
# 513          None -14.87278 -41.27639      baixa
# 525      Operação  -7.85967 -38.78433      ótima
# 534          None  -7.94819 -38.28267      ótima
# 572          None  -8.22944 -39.89722      baixa
# 661          None  -8.08114 -37.31400        boa
# 738          None  -6.59366 -36.75298      baixa
# 748          None  -8.44278 -35.66667      baixa
# 773          None  -7.97944 -38.64417      baixa
# 796          None  -8.08661 -39.42958      ótima
# 861          None  -7.12384 -38.43090      baixa
# 885          None  -6.40168 -37.06942      baixa
# 887          None  -7.94222 -36.99825      baixa
# 913          None  -7.30757 -36.10682      baixa
# 924          None  -7.70618 -36.16814      baixa
# 1026         None  -8.02978 -39.06072        boa
#
#                                                geometry high_risk_high_damage
# 13    POLYGON ((6968637.363 10584182.718, 6968632.54...                  True
# 21    POLYGON ((6914078.966 10582661.841, 6914074.15...                  True
# 35    POLYGON ((6465131.192 9903939.275, 6465126.377...                  True
# 36    POLYGON ((6853119.977 10336942.836, 6853115.16...                  True
# 83    POLYGON ((6570933.685 10397990.721, 6570928.87...                  True
# 88    POLYGON ((6761589.351 10628896.079, 6761584.53...                  True
# 106   POLYGON ((6890342.741 10449436.372, 6890337.92...                  True
# 110   POLYGON ((6740448.690 10613763.367, 6740443.87...                  True
# 123   POLYGON ((6715251.659 10529899.464, 6715246.84...                  True
# 124   POLYGON ((6842544.343 10344722.209, 6842539.52...                  True
# 138   POLYGON ((6507362.709 10432456.618, 6507357.89...                  True
# 144   POLYGON ((6966514.723 10357474.232, 6966509.90...                  True
# 175   POLYGON ((6863655.328 10428592.337, 6863650.51...                  True
# 176   POLYGON ((6279222.726 10708080.471, 6279217.91...                  True
# 184   POLYGON ((6996504.962 10415143.344, 6996500.14...                  True
# 194   POLYGON ((6793686.970 10518387.954, 6793682.15...                  True
# 206   POLYGON ((6910729.647 10353977.308, 6910724.83...                  True
# 227   POLYGON ((6928126.647 10492113.571, 6928121.83...                  True
# 247   POLYGON ((6508746.673 10423075.935, 6508741.85...                  True
# 259   POLYGON ((6952104.953 10345820.214, 6952100.13...                  True
# 287   POLYGON ((6349021.902 10838183.966, 6349017.08...                  True
# 297   POLYGON ((6953133.643 10345722.632, 6953128.82...                  True
# 307   POLYGON ((6503110.071 10350722.356, 6503105.25...                  True
# 316   POLYGON ((6848057.738 10330006.186, 6848052.92...                  True
# 331   POLYGON ((6475374.910 10460539.429, 6475370.09...                  True
# 333   POLYGON ((6899125.051 10283387.228, 6899120.23...                  True
# 346   POLYGON ((6800715.192 10420592.940, 6800710.37...                  True
# 353   POLYGON ((6236133.884 9712124.158, 6236129.069...                  True
# 358   POLYGON ((6693399.524 10549141.651, 6693394.70...                  True
# 361   POLYGON ((6970001.462 10587430.159, 6969996.64...                  True
# 375   POLYGON ((6627044.844 10398513.122, 6627040.02...                  True
# 378   POLYGON ((6579895.051 10128603.630, 6579890.23...                  True
# 380   POLYGON ((6378804.421 10141495.494, 6378799.60...                  True
# 429   POLYGON ((6987429.315 10387733.436, 6987424.50...                  True
# 431   POLYGON ((6948534.357 10343095.447, 6948529.54...                  True
# 460   POLYGON ((6682619.916 10378950.155, 6682615.10...                  True
# 475   POLYGON ((6785065.538 10387941.506, 6785060.72...                  True
# 479   POLYGON ((6758573.759 10600890.424, 6758568.94...                  True
# 485   POLYGON ((6706981.058 10403882.017, 6706976.24...                  True
# 499   POLYGON ((6725411.046 10589915.744, 6725406.23...                  True
# 513   POLYGON ((6350586.102 9646714.596, 6350581.287...                  True
# 525   POLYGON ((6657467.065 10419460.597, 6657462.25...                  True
# 534   POLYGON ((6711467.530 10406544.151, 6711462.71...                  True
# 572   POLYGON ((6534331.119 10384446.311, 6534326.30...                  True
# 661   POLYGON ((6815875.830 10385575.391, 6815871.01...                  True
# 738   POLYGON ((6887074.256 10547995.917, 6887069.44...                  True
# 748   POLYGON ((6992151.689 10333932.685, 6992146.87...                  True
# 773   POLYGON ((6671974.602 10405234.524, 6671969.78...                  True
# 796   POLYGON ((6585963.180 10397818.869, 6585958.36...                  True
# 861   POLYGON ((6700485.056 10499569.836, 6700480.24...                  True
# 885   POLYGON ((6853809.640 10571523.327, 6853804.82...                  True
# 887   POLYGON ((6851121.904 10399037.876, 6851117.08...                  True
# 913   POLYGON ((6952538.669 10463886.136, 6952533.85...                  True
# 924   POLYGON ((6943018.053 10419790.371, 6943013.23...                  True
# 1026  POLYGON ((6626389.666 10402058.889, 6626384.85...                  True
#
# [55 rows x 41 columns]
